# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd

# %% [markdown]
# # Characterizing Unusual Observations

# %% [markdown]
# ## Nathan Kunz

# %% [markdown]
# ### Characterizing Univariate Data

# %% [markdown]
# #### Statistical Summary

# %%
# import the wooldridge module
import wooldridge as woo

# %%
salary = woo.data('ceosal1')
salary
# Out:
#      salary  pcsalary         sales   roe       pcroe  ros  indus  finance  \
# 0      1095        20  27595.000000  14.1  106.400002  191      1        0
# 1      1001        32   9958.000000  10.9  -30.600000   13      1        0
# 2      1122         9   6125.899902  23.5  -16.299999   14      1        0
# 3       578        -9  16246.000000   5.9  -25.700001  -21      1        0
# 4      1368         7  21783.199219  13.8   -3.000000   56      1        0
# ..      ...       ...           ...   ...         ...  ...    ...      ...
# 204     930        10   1509.099976   9.0   20.500000  131      0        0
# 205     525         3   1097.099976  15.5   20.100000   72      0        0
# 206     658        32   4542.600098  12.1   -7.800000   68      0        0
# 207     555         6   2023.000000  13.7  -14.600000   60      0        0
# 208     626         0   1442.500000  14.4  -10.200000   62      0        0
#
#      consprod  utility   lsalary     lsales
# ...

# %%
salary['test'] = True

# %%
salary.test.all()
# Out:
#      salary  pcsalary         sales   roe       pcroe  ros  indus  finance  \
# 0      1095        20  27595.000000  14.1  106.400002  191      1        0
# 1      1001        32   9958.000000  10.9  -30.600000   13      1        0
# 2      1122         9   6125.899902  23.5  -16.299999   14      1        0
# 3       578        -9  16246.000000   5.9  -25.700001  -21      1        0
# 4      1368         7  21783.199219  13.8   -3.000000   56      1        0
# ..      ...       ...           ...   ...         ...  ...    ...      ...
# 204     930        10   1509.099976   9.0   20.500000  131      0        0
# 205     525         3   1097.099976  15.5   20.100000   72      0        0
# 206     658        32   4542.600098  12.1   -7.800000   68      0        0
# 207     555         6   2023.000000  13.7  -14.600000   60      0        0
# 208     626         0   1442.500000  14.4  -10.200000   62      0        0
#
#      consprod  utility   lsalary     lsales  test
# ...

# %%
salary.shape
# Out:
# (209, 13)

# %%
salary.roe.quantile(.99)
# Out:
# 44.49200012207031

# %%
salary.roe.hist(bins =10)
# Out:
# <Axes: >

# %%
np.histogram(salary.roe)
# Out:
# (array([ 7, 39, 84, 43, 20,  5,  3,  6,  1,  1]),
#  array([ 0.5       ,  6.07999992, 11.65999985, 17.23999977, 22.81999969,
#         28.39999962, 33.97999954, 39.55999947, 45.13999939, 50.71999931,
#         56.29999924]))

# %%
True +3
# Out:
# 4

# %%
(salary.salary > 800).sum()
# Out:
# 142

# %%
# Out:
#      salary  pcsalary         sales   roe       pcroe  ros  indus  finance  \
# 0      1095        20  27595.000000  14.1  106.400002  191      1        0
# 1      1001        32   9958.000000  10.9  -30.600000   13      1        0
# 2      1122         9   6125.899902  23.5  -16.299999   14      1        0
# 4      1368         7  21783.199219  13.8   -3.000000   56      1        0
# 5      1145         5   6021.399902  20.0    1.000000   55      1        0
# ..      ...       ...           ...   ...         ...  ...    ...      ...
# 192     803        18   4178.600098  10.7  -29.900000   52      0        0
# 196    1100        58   9470.099609   7.3   76.599998   82      0        0
# 197     959        26   3783.199951  14.6    5.000000   65      0        0
# 203     808       -16   7198.500000  14.7    7.400000   49      0        0
# 204     930        10   1509.099976   9.0   20.500000  131      0        0
#
#      consprod  utility   lsalary     lsales  test
# ...

# %%
# import the wooldridge module
import wooldridge as woo

# use the .data() function to pull down the neccessary dataset
salary = woo.data('ceosal1')
salary.head()
# Out:
#    salary  pcsalary         sales   roe       pcroe  ros  indus  finance  \
# 0    1095        20  27595.000000  14.1  106.400002  191      1        0
# 1    1001        32   9958.000000  10.9  -30.600000   13      1        0
# 2    1122         9   6125.899902  23.5  -16.299999   14      1        0
# 3     578        -9  16246.000000   5.9  -25.700001  -21      1        0
# 4    1368         7  21783.199219  13.8   -3.000000   56      1        0
#
#    consprod  utility   lsalary     lsales
# 0         0        0  6.998509  10.225389
# 1         0        0  6.908755   9.206132
# 2         0        0  7.022868   8.720281
# 3         0        0  6.359574   9.695602
# 4         0        0  7.221105   9.988894

# %% [markdown]
# The describe method allows us to quickly identify any issues in our data that may foil our analysis. Issues include unexpected values, NAs, and more.

# %%
True + True
# Out:
# True

# %%
salary['test'] = True

# %%
salary
# Out:
#      salary  pcsalary         sales   roe       pcroe  ros  indus  finance  \
# 0      1095        20  27595.000000  14.1  106.400002  191      1        0
# 1      1001        32   9958.000000  10.9  -30.600000   13      1        0
# 2      1122         9   6125.899902  23.5  -16.299999   14      1        0
# 3       578        -9  16246.000000   5.9  -25.700001  -21      1        0
# 4      1368         7  21783.199219  13.8   -3.000000   56      1        0
# ..      ...       ...           ...   ...         ...  ...    ...      ...
# 204     930        10   1509.099976   9.0   20.500000  131      0        0
# 205     525         3   1097.099976  15.5   20.100000   72      0        0
# 206     658        32   4542.600098  12.1   -7.800000   68      0        0
# 207     555         6   2023.000000  13.7  -14.600000   60      0        0
# 208     626         0   1442.500000  14.4  -10.200000   62      0        0
#
#      consprod  utility   lsalary     lsales  test
# ...

# %%
import matplotlib.pyplot as plt

# %%
salary.roe.hist(alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mac/Desktop/ucla_python_lab/23f_lec1.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/Users/mac/Desktop/ucla_python_lab/23f_lec1.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> salary.roe.hist(alpha)
#
# NameError: name 'alpha' is not defined

# %%
plt.hist(salary.salary)
# Out:
# (array([177.,  26.,   3.,   0.,   1.,   0.,   0.,   1.,   0.,   1.]),
#  array([  223. ,  1682.9,  3142.8,  4602.7,  6062.6,  7522.5,  8982.4,
#         10442.3, 11902.2, 13362.1, 14822. ]),
#  <BarContainer object of 10 artists>)

# %%
# Describing the data
salary.describe()
# Out:
#              salary    pcsalary         sales         roe       pcroe  \
# count    209.000000  209.000000    209.000000  209.000000  209.000000
# mean    1281.119617   13.282297   6923.793282   17.184211   10.800478
# std     1372.345308   32.633921  10633.271088    8.518509   97.219399
# min      223.000000  -61.000000    175.199997    0.500000  -98.900002
# 25%      736.000000   -1.000000   2210.300049   12.400000  -21.200001
# 50%     1039.000000    9.000000   3705.199951   15.500000   -3.000000
# 75%     1407.000000   20.000000   7177.000000   20.000000   19.500000
# max    14822.000000  212.000000  97649.898438   56.299999  977.000000
#
#               ros       indus     finance    consprod     utility     lsalary  \
# count  209.000000  209.000000  209.000000  209.000000  209.000000  209.000000
# mean    61.803828    0.320574    0.220096    0.287081    0.172249    6.950386
# std     68.177052    0.467818    0.415306    0.453486    0.378503    0.566374
# ...

# %%
# Get information about the data types
# Also data structure
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   salary    209 non-null    int64
#  1   pcsalary  209 non-null    int64
#  2   sales     209 non-null    float64
#  3   roe       209 non-null    float64
#  4   pcroe     209 non-null    float64
#  5   ros       209 non-null    int64
#  6   indus     209 non-null    int64
#  7   finance   209 non-null    int64
#  8   consprod  209 non-null    int64
#  9   utility   209 non-null    int64
#  10  lsalary   209 non-null    float64
#  11  lsales    209 non-null    float64
# dtypes: float64(5), int64(7)
# memory usage: 19.7 KB

# %%
# Count the number of null values in every column
salary.isnull().sum()
# Out:
# salary      0
# pcsalary    0
# sales       0
# roe         0
# pcroe       0
# ros         0
# indus       0
# finance     0
# consprod    0
# utility     0
# lsalary     0
# lsales      0
# dtype: int64

# %%
# Check if there are any null values in the dataframe
# True if any contain an NA
salary.isnull().any()
# Out:
# salary      False
# pcsalary    False
# sales       False
# roe         False
# pcroe       False
# ros         False
# indus       False
# finance     False
# consprod    False
# utility     False
# lsalary     False
# lsales      False
# dtype: bool

# %% [markdown]
# #### Histograms

# %%
# Set the figure size
plt.figure(figsize = (14, 6))

# Plot the data 
plt.hist(salary["roe"], alpha = .5)

# add labels
plt.title("Return on Equity")
plt.ylabel("Frequency")
plt.xlabel("ROE")

# add grid lines
plt.grid()

# %%
# very fast plots can be produced with the pandas layer
salary["roe"].hist()
# Out:
# <Axes: >

# %%
#math module lets you use a custom base for log
import math 
# Sturges method
bins = int(np.round(1 + math.log(len(salary),2)))

#plotting
plt.figure(figsize = (16, 8))
plt.hist(salary.roe, alpha = .5, bins = bins)
plt.plot()
# Out:
# []

# %%
# One method for selecting bin number
bins = np.round(1 + math.log(len(salary),2))

plt.figure(figsize = (16, 8))
plt.hist(salary.roe, alpha = .5, bins = "sturges")
plt.plot()
# Out:
# []

# %%
# create FD function
def bins_fd(series):
    numerator = (len(series)**(1/3)*(series.max()-series.min()))
    denominator = (2*(salary.roe.quantile(.75)-salary.roe.quantile(.25)))
    
    return int(np.round(numerator/denominator))

plt.figure(figsize = (16, 8))
plt.hist(salary.roe, alpha = .5, bins = bins_fd(salary.roe))
plt.plot()
# Out:
# []

# %%
plt.hist(salary.roe, alpha = .5, bins = "fd")
plt.title("FD Bin Number")
plt.show()

# %%
plt.hist(salary.roe, alpha = .5, bins = "sturges")
plt.title("Sturges Bin Number")
plt.show()

# %% [markdown]
# ### Density estimation

# %%
import seaborn as sns

# %%
plt.figure(figsize=(5,5))
# Density plot
sns.kdeplot(salary.roe, color = "red")
# Out:
# <Axes: xlabel='roe', ylabel='Density'>

# %%
plt.figure(figsize=(5,5))
# Rug plot
sns.rugplot(salary.roe, color = "black")
# Out:
# <Axes: xlabel='roe'>

# %%
plt.figure(figsize=(5,5))
sns.histplot(salary.roe, stat = "density")
# Out:
# <Axes: xlabel='roe', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
plt.title("Histogram of Return on Equity")
sns.histplot(salary.roe, stat = "density")
sns.kdeplot(salary.roe, color = "red")
sns.rugplot(salary.roe, color = "black")

plt.grid()

# %% [markdown]
# #### Quantile-Quantile Plot

# %%
import numpy as np 
import scipy.stats as stats

stats.probplot(salary.roe, dist="norm", plot=plt)
plt.show()

# %%
# create a sample of the same size as the salary dataset
# from the standard normal distribution
norm_sam = np.random.normal(0, 1, salary.shape[0])

# How a sample drawn from a normal distribution may look
stats.probplot(norm_sam, dist="norm", plot = plt)
plt.show()

# %% [markdown]
# Below I show how q-q plots can be created from scratch if you're interested in the mechanics!

# %%
# sort the data
roe_sort = salary.roe.sort_values()

# Divide the standard and scaled normal distirbutions into slices of equal size
# Each point in the original sample is a "quantile"
norm_quants = stats.norm.ppf(np.linspace(.001, .999, len(roe_sort)))
norm_quantsy = stats.norm(roe_sort.mean(), roe_sort.std()).ppf(np.linspace(.001, .999, len(roe_sort)))

# Plot the data
plt.scatter(norm_quants, roe_sort, color = "blue")
plt.plot(norm_quants, norm_quantsy, color = "red")
plt.title("Q-Q Plot")
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Observed Values")
plt.show()

# %% [markdown]
# #### Boxplots

# %%
# matplotlib
plt.figure(figsize=(5,6))
plt.boxplot(salary.roe)
plt.ylabel("ROE")
plt.show()

# %%
# seaborn
plt.figure(figsize = (5, 6))
sns.boxplot(data = salary.roe)
plt.ylabel("ROE")
plt.show()

# %%
# create a list containing the two series of people within different industries
data = [salary[salary.indus == 0].roe, salary[salary.indus == 1].roe]
plt.figure(figsize=(5,6))
plt.boxplot(data)
plt.ylabel("ROE")
plt.xticks([1,2, 3], ["0", "cat", 'doG'])
plt.show()

# %%
# seaborn
plt.figure(figsize = (5, 6))
sns.boxplot(x = "indus", y = "roe", data = salary)
plt.ylabel("ROE")
plt.show()

# %% [markdown]
# ### Characterizing Bivariate Data

# %% [markdown]
# #### Matplotlib Scatterplot

# %%
plt.figure(figsize = (6, 6))
# Create scatterplot betwene two variables
plt.scatter(salary["roe"], salary["salary"],)
plt.title("Basic Scatterplot")
plt.ylabel("Salary (Thousands)")
plt.xlabel("ROE (%)")
plt.grid()

# %%
m,b = np.polyfit(salary["roe"], salary["salary"], deg = 1)
print("The slope of the regression line is:", m, "The Intercept is:", b)
# Out:
# The slope of the regression line is: 18.501186345214922 The Intercept is: 963.1913364725574

# %%
plt.figure(figsize = (6, 6))

# Create a series of equaly spaced values
x_range = np.linspace(0, salary.roe.max(), 100)

# Apply y=mx+b
plt.plot(x_range, m*x_range+b)
plt.title("Basic Scatterplot")
plt.ylabel("Salary (Thousands)")
plt.xlabel("ROE (%)")
plt.grid()

# %%
plt.figure(figsize = (15, 8))

# combining the two plots
plt.scatter(salary["roe"], salary["salary"])
plt.plot(x_range, m*x_range+b, color = "red")
plt.title("Scatter Plot with Regression Line")
plt.ylabel("Salary (Thousands)")
plt.xlabel("ROE (%)")
plt.grid()

# %% [markdown]
# #### Seaborn Scatterplots

# %%
plt.figure(figsize = (7, 6))
sns.scatterplot(data = salary, x = "roe", y = "salary")
plt.title("Salary vs Return on Stocks Scatter")
plt.show()

# %%
# lmplot allows us to include different regression lines
sns.lmplot(data = salary, x = "roe", y = "salary",
           line_kws= {"color":"red"}, height = 7, aspect = 1)
plt.title("Salary vs Return on Stocks With Regression Line")
plt.show()

# %%
# Lowess with return on stock
sns.lmplot(data = salary, x = "ros", y = "salary", lowess = True,
           line_kws= {"color":"red"}, height = 7, aspect = 1)
plt.title("Salary vs Return on Stocks With Lowess Smoother")
plt.show()

# %%
sns.scatterplot(data = salary, x = "roe", y = "salary", hue = "finance")
# Out:
# <Axes: xlabel='roe', ylabel='salary'>

# %%
plt.figure(figsize= (10, 6))
sns.lmplot(data = salary, x = "roe", y = "salary", 
           hue = "finance", height = 7, aspect = 1.5)
plt.title("Salary vs ROE With Regression Line Finance vs Non-Finance")
plt.show()

# %%
plt.figure(figsize= (10, 6))
sns.lmplot(data = salary, x = "roe", y = "salary", 
           hue = "finance", lowess = True, height = 7, aspect = 1.5)
plt.title("Salary vs ROE With Lowess Smoother Finace vs Non-Finance")
plt.show()

# %% [markdown]
# ### Pairplot

# %%
salary
# Out:
#      salary  pcsalary         sales   roe       pcroe  ros  indus  finance  \
# 0      1095        20  27595.000000  14.1  106.400002  191      1        0
# 1      1001        32   9958.000000  10.9  -30.600000   13      1        0
# 2      1122         9   6125.899902  23.5  -16.299999   14      1        0
# 3       578        -9  16246.000000   5.9  -25.700001  -21      1        0
# 4      1368         7  21783.199219  13.8   -3.000000   56      1        0
# ..      ...       ...           ...   ...         ...  ...    ...      ...
# 204     930        10   1509.099976   9.0   20.500000  131      0        0
# 205     525         3   1097.099976  15.5   20.100000   72      0        0
# 206     658        32   4542.600098  12.1   -7.800000   68      0        0
# 207     555         6   2023.000000  13.7  -14.600000   60      0        0
# 208     626         0   1442.500000  14.4  -10.200000   62      0        0
#
#      consprod  utility   lsalary     lsales
# ...

# %%
# subsetting a manageable portion of the data
data_subset= salary[["salary", "pcsalary", "ros", "sales", "roe", "finance"]]

# build pairplot
sns.pairplot(data_subset, hue = "finance", kind = 'reg')

# %% [markdown]
# ### Jittering Scatterplots

# %%
sns.lmplot(x = "finance", y = "salary", data = salary)
plt.title("Finance and Salary: No Jitter")
# Out:
# Text(0.5, 1.0, 'Finance and Salary: No Jitter')

# %%
sns.lmplot(x = "finance", y = "salary", data = salary, x_jitter = .05)
plt.title("Finance and Salary: X Jitter")
# Out:
# Text(0.5, 1.0, 'Finance and Salary: X Jitter')

# %% [markdown]
# ### Regression in Python

# %% [markdown]
# #### Manual

# %%
# subset the x and y variables
x = salary['roe']
y = salary['salary']

# calculate the covariance and variance 
cov_xy = np.cov(x,y)[1,0] # returns a covariance matrix, we want the covariance between x and y
var_x = np.var(x, ddof = 1)

# Calculate coefficients
b1 = cov_xy/var_x
b0 = np.mean(y) - b1*np.mean(x)

print("The slope of the regression line is:", b1, "and the intercept is:", b0)
# Out:
# The slope of the regression line is: 18.50118634521492 and the intercept is: 963.191336472558

# %%
import statsmodels.formula.api as smf

# %%
# syntax is model = sm.OLS('y~x', data = sampl)
reg = smf.ols('salary ~ roe', data= salary)
results = reg.fit()

# %%
# Access the estimated parameters in our results
results.params
# Out:
# Intercept    963.191336
# roe           18.501186
# dtype: float64

# %%
# the fitted values attribute contains 209 
# predicted y values for each observation
results.fittedvalues
# Out:
# 0      1224.058071
# 1      1164.854261
# 2      1397.969216
# 3      1072.348338
# 4      1218.507712
#           ...
# 204    1129.702014
# 205    1249.959725
# 206    1187.055698
# 207    1216.657586
# 208    1229.608413
# Length: 209, dtype: float64

# %%
plt.figure(figsize = (16, 9))

# plot the observed values
plt.scatter(salary['roe'], salary['salary'])

# plot roe vs the predicted or fitted values
plt.plot(salary['roe'], results.fittedvalues, color = "orange")

# add labels
plt.title("CEO Salary vs Return on Investment")
plt.xlabel("CEO Salary (Thousands)")
plt.ylabel("ROE")

plt.plot()
# Out:
# []

# %% [markdown]
# ### Residuals

# %%
# calculate the fitted values from our estimated coefficients
y_hat = b0 + b1 * salary['roe']

# calculate the residuals
u_hat = salary["salary"] - y_hat

u_hat
# Out:
# 0     -129.058071
# 1     -163.854261
# 2     -275.969216
# 3     -494.348338
# 4      149.492288
#           ...
# 204   -199.702014
# 205   -724.959725
# 206   -529.055698
# 207   -661.657586
# 208   -603.608413
# Length: 209, dtype: float64

# %%
reg = smf.ols('salary ~ roe', data= salary)
results = reg.fit()

# residuals are also stored in results from statsmodels
results.resid
# Out:
# 0     -129.058071
# 1     -163.854261
# 2     -275.969216
# 3     -494.348338
# 4      149.492288
#           ...
# 204   -199.702014
# 205   -724.959725
# 206   -529.055698
# 207   -661.657586
# 208   -603.608413
# Length: 209, dtype: float64

# %%
# confirm property 1
prop1 = u_hat.mean()

# confirm property 2
prop2 = np.cov(x, u_hat)

#confirm property 3
y_barp3 = b0+b1*np.mean(x)
y_bar = np.mean(y)

# %%
print("The mean of our residuals is: ", prop1)
print("The covariance between x and u: ", prop2[0,1])
print("The mean of y is", y_bar, "and the mean calculated from the parameters is:", y_barp3)
# Out:
# The mean of our residuals is:  -1.7406597163118243e-14
# The covariance between x and u:  2.098833927168296e-13
# The mean of y is 1281.1196172248804 and the mean calculated from the parameters is: 1281.1196172248804
